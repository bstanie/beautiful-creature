# %%
import json
import os
import sys
import pathlib
from collections import defaultdict

import pymongo
import transformers
from tqdm import tqdm_notebook
from transformers import pipeline
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
from matplotlib import pyplot as plt
import plotly.express as px
from binance.client import Client
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
PROJECT_ROOT = pathlib.Path.cwd().parent
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
print(PROJECT_ROOT)
# Out:
# /home/stanislav/Workspace/beautiful-creature

# %%
import project_settings
from project_settings import BINANCE_KEY, BINANCE_SECRET

# %%
name_mapping = {"Cardano": "ADAUSDT", "Ripple": "XRPUSDT", "Ethereum": "ETHUSDT", "Dogecoin": "DOGEUSDT",
                "Polkadot": "DOTUSDT", "Litecoin": "LTCUSDT", "Solana": "SOLUSDT",
                "VeChain": "VETUSDT", "FileCoin": "FILUSDT", "Monero": "XMRUSDT"}

symbol = "FILUSDT"

# %%
client = Client(BINANCE_KEY, BINANCE_SECRET)
klines = client.get_historical_klines(symbol, Client.KLINE_INTERVAL_1DAY, start_str="1 Jan, 2021")
print("History size:", len(klines))
# Out:
# History size: 191

# %%
price = []
time = []
volume = []
for c in klines:
    time.append(datetime.datetime.fromtimestamp(int(str(c[0])[:-3])))
    price.append(float(c[4]))
    volume.append(float(c[5]))

hist_prices = pd.DataFrame({"time": time, "price": price, 'volume': volume})
hist_prices.head()
hist_prices = hist_prices.set_index("time")
hist_prices[hist_prices.columns] = StandardScaler().fit_transform(hist_prices)
hist_prices.index.name = "date"

# %%
plt.figure(figsize=(10, 7))
sns.lineplot(x=hist_prices.index, y=hist_prices["price"])
plt.title(symbol)
# Out:
# Text(0.5, 1.0, 'FILUSDT')

# %%
def fetch_reddit_data(symbol: str):
    history_data_path = PROJECT_ROOT / "data" / 'reddit_crypto_stat.csv'
    df = pd.read_csv(history_data_path)
    df["keyword"] = df["keyword"].map(name_mapping)
    df = df.set_index(['keyword', 'date'])
    df = df.sort_index()
    sub_df = df.loc[symbol,:].copy()
    sub_df.loc[:,sub_df.columns] = StandardScaler().fit_transform(sub_df)
    sub_df.loc[:,sub_df.columns] = SimpleImputer().fit_transform(sub_df)
    sub_df.index = pd.to_datetime(sub_df.index, yearfirst=True)
    sub_df = sub_df.sort_index()
    return sub_df

def fetch_search_data(symbol: str):

    connection = pymongo.MongoClient(
        project_settings.MONGODB_SERVER,
        project_settings.MONGODB_PORT)
    google_trends_collection_name = f"{project_settings.MONGODB_GOOGLE_TRENDS_COLLECTION}_by_day"
    db = connection[project_settings.MONGODB_DB_NAME]
    google_trends_collection = db[google_trends_collection_name]
    data = google_trends_collection.find({})
    df = pd.DataFrame(data)
    df = df.drop("_id",axis=1)
    df = df.set_index("date")
    # df.index = pd.to_datetime(df.index, yearfirst=True)
    df[df.columns] = StandardScaler().fit_transform(df)
    df.columns = list(map(lambda x: name_mapping[x], df.columns))
    sub_df = df[[symbol]]
    sub_df.columns = ["search"]
    return sub_df

# %%
hist_reddit = fetch_reddit_data(symbol)

# %%
hist_search = fetch_search_data(symbol)

# %%
hist_prices = hist_prices.loc[hist_reddit.index[0]:]
hist_prices.index = pd.Series(hist_prices.index).apply(lambda x: datetime.datetime.combine(x.date(),datetime.datetime.min.time()))

# %%
merge_df = hist_reddit.join(hist_prices).join(hist_search)
for col in merge_df.columns:
    merge_df[col] = merge_df[col].rolling(5).mean()

# %%
px.defaults.width = 1000
px.defaults.height = 600
pd.options.plotting.backend = "plotly"

# merge_df = merge_df.reset_index()
merge_df.plot()
# Out:
# <div>                            <div id="ee60aa59-1d3d-4d60-b43e-0028bb7bcf49" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee60aa59-1d3d-4d60-b43e-0028bb7bcf49")) {                    Plotly.newPlot(                        "ee60aa59-1d3d-4d60-b43e-0028bb7bcf49",                        [{"hovertemplate":"variable=num_keyword_posts<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"num_keyword_posts","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"num_keyword_posts","showlegend":true,"type":"scattergl","x":["2021-01-02T00:00:00","2021-01-03T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-09T00:00:00","2021-01-10T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-16T00:00:00","2021-01-17T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-23T00:00:00","2021-01-24T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-01-30T00:00:00","2021-01-31T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-13T00:00:00","2021-02-14T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-20T00:00:00","2021-02-21T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-02-27T00:00:00","2021-02-28T00:00:00","2021-03-01T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-06T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-13T00:00:00","2021-03-14T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-28T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-02T00:00:00","2021-04-03T00:00:00","2021-04-04T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-10T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-17T00:00:00","2021-04-18T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-24T00:00:00","2021-04-25T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-01T00:00:00","2021-05-02T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-08T00:00:00","2021-05-09T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-15T00:00:00","2021-05-16T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-22T00:00:00","2021-05-23T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-29T00:00:00","2021-05-30T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-05T00:00:00","2021-06-06T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-12T00:00:00","2021-06-13T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-0 ...
